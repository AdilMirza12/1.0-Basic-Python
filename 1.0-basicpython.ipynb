# %%
## Bssic Syntax Rules in python
## Case sensitivity- Python is case sensitive

name="Krish"
Name="Naik"

print(name)
print(Name)
# Out:
# Krish
# Naik

# %%
## Intendatation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age>32:
    
    print(age)
    
print(age)
# Out:
# 32

# %%
## This is a single line comment
print("Hello world")
# Out:
# Hello world

# %%
## Line Continuation

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Type inference
variable=10
print(type(variable))
variable="Adil"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=23
if age>20:
    print(age)
# Out:
# 23

# %%
## Code explame of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
